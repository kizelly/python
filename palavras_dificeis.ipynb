# %% [markdown]
# <a href="https://colab.research.google.com/github/kizelly/python/blob/main/palavras_dificeis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #palavras dificeis- saeb  🐻   💓
#
# 👼![9157d8c73ecc5561598536047bb41ed9.jpg gatinho](data:application/octet-stream;base64,...)

# %% [markdown]
# #**Enunciado** **1**:  😰 ⌛ ❓

# %% [markdown]
# aula 8  🥰 🐻 ♥

# %% [markdown]
#   print" sou seu assistente virtual, \n"
#   nome = input ("digite seu nome: ")
#   print(f"olá, " {nome} . qual é sua dúvida hoje?")
#   respostas = input ("qual asunto que eseja tratar: Matemática , pyton , javascript

# %%
print (" sou seu assistente virtual, \n")
nome = input("digite seu nome: ")
print(f"olá,  {nome} . qual é sua dúvida hoje?")
respostas = input("qual asunto que eseja tratar: Matemática , pyton , javascript: ")
print(f"Que bom, {nome}, vamos falar sobre {resposta}")
if resposta=="python":
  print("Ótimo, vamos falar sobre pyhon! ")
elif resposta=="matemática":
  print("Perfeito, vamos resolver umas questões de matmática!")
# Out:
#  sou seu assistente virtual,
